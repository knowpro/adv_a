# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
hos = pd.read_csv(r"C:/Hogwarts/advanced_analytics/Datasets/Housing.csv")

# %%
hos
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
ctab = pd.crosstab(hos['prefarea'], hos['gashw'])
ctab
# Out:
# gashw      no  yes
# prefarea
# no        396   22
# yes       125    3

# %%
test_statistic, p_value, df, expected_frequencies = chi2_contingency(ctab)
print("Expected Frequencies :\n", expected_frequencies,"\n")
print("p value : ",p_value)
# Out:
# Expected Frequencies :
#  [[398.86080586  19.13919414]
#  [122.13919414   5.86080586]]
#
# p value :  0.25389003711306934
