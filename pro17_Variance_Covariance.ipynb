# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

# %%
a= np.array([2,5,6,7,10])
b= np.array([30,24,20,17,7])

# %%
pizza = pd.read_csv(r"C:/Hogwarts/advanced_analytics/Datasets/pizza.csv")

# %%
pizza['Promote'].cov(pizza['Sales'])
# Out:
# 15468.17543859649

# %%
# Variance Covariance Matrix
np.cov(pizza['Promote'], pizza['Sales'])
# Out:
# array([[   658.04093567,  15468.1754386 ],
#        [ 15468.1754386 , 367714.11695906]])

# %%
pizza.cov()
# Out:
#               Promote          Sales
# Promote    658.040936   15468.175439
# Sales    15468.175439  367714.116959

# %%
# Correlation
pizza['Promote'].corr(pizza['Sales'])
# Out:
# 0.9943916799675253

# %%
sns.scatterplot(data = 'pizza',
               x= pizza['Promote'],
               y= pizza['Sales'])
plt.show()

# %% [markdown]
# # Relation between Promote and Promote

# %%
pizza['Promote'].corr(pizza['Promote'])
# Out:
# 0.9999999999999999

# %%
sns.scatterplot(data = 'pizza',
               x= pizza['Promote'],
               y= pizza['Promote'])
plt.show()
