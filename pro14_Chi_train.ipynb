# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
trn = pd.read_csv(r"C:/Hogwarts/advanced_analytics/Datasets/train_v9.csv")

# %%
trn['Item_Fat_Content'] = trn['Item_Fat_Content'].replace({'low fat': 'Low Fat',
                                                               'LF': 'Low Fat',
                                                              'reg': 'Regular'})
trn
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
ctab = pd.crosstab(trn['Item_Fat_Content'], trn['Item_Type'])
ctab
# Out:
# Item_Type         Baking Goods  Breads  Breakfast  Canned  Dairy  \
# Item_Fat_Content
# Low Fat                    329     140         41     341    418
# Regular                    319     111         69     308    264
#
# Item_Type         Frozen Foods  Fruits and Vegetables  Hard Drinks  \
# Item_Fat_Content
# Low Fat                    450                    630          214
# Regular                    406                    602            0
#
# Item_Type         Health and Hygiene  Household  Meat  Others  Seafood  \
# Item_Fat_Content
# Low Fat                          520        910   170     169       37
# Regular                            0          0   255       0       27
#
# Item_Type         Snack Foods  Soft Drinks  Starchy Foods
# Item_Fat_Content
# Low Fat                   692          374             82
# Regular                   508           71             66

# %%
test_statistic, p_value, df, expected_frequencies = chi2_contingency(ctab)
print("p value : ", p_value)
# Out:
# p value :  0.0
