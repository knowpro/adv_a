# %%
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %%
auto_ins = pd.read_csv(r"C:/Hogwarts/advanced_analytics/Datasets/Insure_auto.csv")

# %%
auto_ins.head()
# Out:
#   Branch  Home  Automobile  Operating_Cost
# 0    B01   400        1200          124000
# 1    B02   350         360           71000
# 2    B03   600         800          136000
# 3    B04   800        1800          219000
# 4    B05   900        1600          230000

# %%
auto_ins['Home'].cov(auto['Automobile'])
# Out:
# 58177.777777777774

# %%
ind_ls = list(auto_ins.columns)
print(ind_ls)
# Out:
# ['Branch', 'Home', 'Automobile', 'Operating_Cost']

# %%
#for ind in ind_ls:
#    auto_ins['Branch'].cov(auto_ins[ind])

# %%
auto_ins['Home'].cov(auto['Operating_Cost'])
# Out:
# 14146666.666666666

# %%
sns.heatmap(auto.corr(),
            xticklabels=auto.corr().columns,
            yticklabels=auto.corr().columns,
            annot = True)  
plt.show()

# %%
sns.pairplot(auto,
            diag_kind="kde")
